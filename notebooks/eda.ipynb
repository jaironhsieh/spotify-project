# %%
import matplotlib.pyplot as plt
import pandas as pd

artists = pd.read_csv("../data/artists.csv")
tracks = pd.read_csv("../data/tracks.csv")
#tracks["duration_ms"].head
#tracks.head
figure, axis = plt.subplots(1,2)

axis[0].plot(tracks["duration_ms"], tracks["popularity"], "ro")

axis[1].plot(tracks["energy"], tracks["popularity"], "bo")
plt.show()
